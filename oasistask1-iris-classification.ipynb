# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Read the dataset file
data = pd.read_csv('/kaggle/input/iriscsv/Iris.csv', index_col = 0)

# %%
#Display the first five rows of the dataframe
print(data.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Displaying the information of the dataframe
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB
# None

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
# check there is no null values and check for missing values
print(data.isna().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Check for duplicates
print(data.duplicated(keep = False).value_counts())
print(data[data.duplicated(keep = False)])
# Out:
# False    145
# True       5
# Name: count, dtype: int64
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 10             4.9           3.1            1.5           0.1     Iris-setosa
# 35             4.9           3.1            1.5           0.1     Iris-setosa
# 38             4.9           3.1            1.5           0.1     Iris-setosa
# 102            5.8           2.7            5.1           1.9  Iris-virginica
# 143            5.8           2.7            5.1           1.9  Iris-virginica

# %%
#Drop duplicates
data = data.drop_duplicates(keep = 'first').copy()
print(data.shape)
# Out:
# (147, 5)

# %%
#Reset the index of the dataframe

data = data.reset_index(drop = True)

# %%
#Split the dataframe into X(features) and y(target or labels)
X = data.iloc[:, 0:4].values
y = data['Species'].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (147, 4)
# (147,)

# %%
#Normalization on X
scaler = MinMaxScaler()
scaler.fit(X)
X_scaled = scaler.fit_transform(X)

# %%
#Convert target using LabelEncoder
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# %%
#Categorically encoding the labels

num_categories = 3
y_onehot = keras.utils.to_categorical(y_encoded, num_categories)

# %%
#convert X_scaled and y_onehot into train and valid data

X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y_onehot,
                                                     test_size = 0.2,
                                                     random_state = 42)

# %%
#Define a model

model = Sequential()
model.add(Dense(units = 512, activation = 'relu', input_shape = (4,)))
model.add(Dense(units = 512, activation = 'relu'))
model.add(Dense(units = 512, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = num_categories, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2560
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 529,411
# Trainable params: 529,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compiling the model

model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(X_train, y_train,
          epochs = 100,
          verbose = 1,
          validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 8s 84ms/step - loss: 0.9806 - accuracy: 0.4701 - val_loss: 0.7286 - val_accuracy: 0.6667
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6426 - accuracy: 0.6667 - val_loss: 0.5074 - val_accuracy: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4782 - accuracy: 0.7179 - val_loss: 0.5433 - val_accuracy: 0.7000
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4334 - accuracy: 0.8034 - val_loss: 0.6953 - val_accuracy: 0.6667
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5131 - accuracy: 0.7863 - val_loss: 0.4165 - val_accuracy: 0.6667
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3910 - accuracy: 0.7778 - val_loss: 0.4124 - val_accuracy: 0.7000
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3299 - accuracy: 0.8803 - val_loss: 0.5336 - val_accuracy: 0.6667
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4978 - accuracy: 0.7009 - val_loss: 0.3164 - val_accuracy: 0.8667
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3504 - accuracy: 0.8462 - val_loss: 0.3129 - val_accuracy: 0.9333
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3637 - accuracy: 0.8120 - val_loss: 0.2879 - val_accuracy: 0.8667
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2485 - accuracy: 0.9231 - val_loss: 0.3119 - val_accuracy: 0.9000
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1559 - accuracy: 0.9573 - val_loss: 0.1204 - val_accuracy: 0.9333
# Epoch 75/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0501 - accuracy: 0.9658 - val_loss: 0.1392 - val_accuracy: 0.9333
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0576 - accuracy: 0.9658 - val_loss: 0.1610 - val_accuracy: 0.9333
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0510 - accuracy: 0.9744 - val_loss: 0.1034 - val_accuracy: 0.9333
# Epoch 78/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0986 - accuracy: 0.9487 - val_loss: 0.1006 - val_accuracy: 0.9333
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0776 - accuracy: 0.9487 - val_loss: 0.0965 - val_accuracy: 0.9667
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0635 - accuracy: 0.9829 - val_loss: 0.0960 - val_accuracy: 0.9667
# Epoch 81/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0426 - accuracy: 0.9829 - val_loss: 0.0885 - val_accuracy: 0.9667
# Epoch 82/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0714 - accuracy: 0.9744 - val_loss: 0.1225 - val_accuracy: 0.9333
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0429 - accuracy: 0.9744 - val_loss: 0.1293 - val_accuracy: 0.9333
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0425 - accuracy: 0.9915 - val_loss: 0.1705 - val_accuracy: 0.9333
# Epoch 85/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1125 - accuracy: 0.9658 - val_loss: 0.1079 - val_accuracy: 0.9333
# Epoch 86/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0988 - accuracy: 0.9487 - val_loss: 0.1422 - val_accuracy: 0.9333
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0495 - accuracy: 0.9744 - val_loss: 0.1360 - val_accuracy: 0.9333
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0383 - accuracy: 0.9915 - val_loss: 0.1215 - val_accuracy: 0.9333
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.9829 - val_loss: 0.1361 - val_accuracy: 0.9333
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1213 - accuracy: 0.9487 - val_loss: 0.1373 - val_accuracy: 0.9333
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0877 - accuracy: 0.9573 - val_loss: 0.1675 - val_accuracy: 0.9333
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0393 - accuracy: 0.9829 - val_loss: 0.1419 - val_accuracy: 0.9000
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9744 - val_loss: 0.3605 - val_accuracy: 0.9000
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1571 - accuracy: 0.9487 - val_loss: 0.1090 - val_accuracy: 0.9667
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0345 - accuracy: 0.9829 - val_loss: 0.1473 - val_accuracy: 0.9333
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0492 - accuracy: 0.9829 - val_loss: 0.1157 - val_accuracy: 0.9333
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0426 - accuracy: 0.9915 - val_loss: 0.0960 - val_accuracy: 0.9333
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0592 - accuracy: 0.9829 - val_loss: 0.1442 - val_accuracy: 0.9333
# Epoch 99/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1368 - accuracy: 0.9402 - val_loss: 0.1033 - val_accuracy: 0.9667
# Epoch 100/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0355 - accuracy: 0.9915 - val_loss: 0.1299 - val_accuracy: 0.9333

# %%
#Print actual and predicted value

y_pred = model.predict(X_valid)

actual = np.argmax(y_valid, axis = 1)
predicted = np.argmax(y_pred, axis = 1)

print(f"Actual:    {actual}")
print(f"Predicted: {predicted}")
# Out:
# 1/1 [==============================] - 0s 92ms/step
# Actual:    [2 1 2 0 2 0 1 0 1 0 0 1 2 1 2 1 0 1 2 0 0 2 0 2 1 0 1 2 1 0]
# Predicted: [2 1 2 0 2 0 1 0 2 0 0 1 2 1 2 2 0 1 2 0 0 2 0 2 1 0 1 2 1 0]
